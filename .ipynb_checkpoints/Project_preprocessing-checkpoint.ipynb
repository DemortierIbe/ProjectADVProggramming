# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read CSV files
df_2015 = pd.read_csv('2015.csv')
df_2016 = pd.read_csv('2016.csv')
df_2017 = pd.read_csv('2017.csv')
df_2018 = pd.read_csv('2018.csv')
df_2019 = pd.read_csv('2019.csv')

# Display the first few rows of one of the dataframes to ensure it's loaded correctly
df_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
df_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
df_2018.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
df_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
df_2015.shape
# Out:
# (158, 12)

# %%
df_2016.shape
# Out:
# (157, 13)

# %%
df_2017.shape
# Out:
# (155, 12)

# %%
df_2018.shape
# Out:
# (156, 9)

# %%
df_2019.shape
# Out:
# (156, 9)

# %%
print("Column names for 2015 dataset:")
print(df_2015.columns)

print("\nColumn names for 2016 dataset:")
print(df_2016.columns)

print("\nColumn names for 2017 dataset:")
print(df_2017.columns)

print("\nColumn names for 2018 dataset:")
print(df_2018.columns)

print("\nColumn names for 2019 dataset:")
print(df_2019.columns)
# Out:
# Column names for 2015 dataset:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')
#
# Column names for 2016 dataset:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')
#
# Column names for 2017 dataset:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
# ...

# %%
# Columns to remove from each dataset
columns_to_remove_2015 = ['Standard Error', 'Dystopia Residual']
columns_to_remove_2016 = ['Lower Confidence Interval', 'Upper Confidence Interval', 'Dystopia Residual']
columns_to_remove_2017 = ['Whisker.high', 'Whisker.low', 'Dystopia.Residual']  # Corrected columns for 2017

# Remove specified columns from df_2015
df_2015 = df_2015.drop(columns=columns_to_remove_2015)

# Remove specified columns from df_2016
df_2016 = df_2016.drop(columns=columns_to_remove_2016)

# Remove specified columns from df_2017
df_2017 = df_2017.drop(columns=columns_to_remove_2017)

# Verify the column names for each DataFrame after removing columns
print("Column names after removing specified columns:")
print("2015 dataset:", df_2015.columns)
print("2016 dataset:", df_2016.columns)
print("2017 dataset:", df_2017.columns)
# Columns for 2018 and 2019 datasets remain unchanged
# Out:
# Column names after removing specified columns:
# 2015 dataset: Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity'],
#       dtype='object')
# 2016 dataset: Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity'],
#       dtype='object')
# 2017 dataset: Index(['Country', 'Happiness.Rank', 'Happiness.Score',
#        'Economy..GDP.per.Capita.', 'Family', 'Health..Life.Expectancy.',
#        'Freedom', 'Generosity', 'Trust..Government.Corruption.'],
#       dtype='object')

# %%
df_2015.shape
# Out:
# (158, 10)

# %%
df_2016.shape
# Out:
# (157, 10)

# %%
df_2017.shape
# Out:
# (155, 9)

# %%
df_2018.shape
# Out:
# (156, 9)

# %%
df_2019.shape
# Out:
# (156, 9)

# %%
# Remove rows with empty or null values from df_2015
df_2015 = df_2015.dropna()

# Remove rows with empty or null values from df_2016
df_2016 = df_2016.dropna()

# Remove rows with empty or null values from df_2017
df_2017 = df_2017.dropna()

# Remove rows with empty or null values from df_2018
df_2018 = df_2018.dropna()

# Remove rows with empty or null values from df_2019
df_2019 = df_2019.dropna()

# Verify the shape of each DataFrame after removing rows with empty or null values
print("Shape after removing rows with empty or null values:")
print("2015 dataset:", df_2015.shape)
print("2016 dataset:", df_2016.shape)
print("2017 dataset:", df_2017.shape)
print("2018 dataset:", df_2018.shape)
print("2019 dataset:", df_2019.shape)
# Out:
# Shape after removing rows with empty or null values:
# 2015 dataset: (158, 10)
# 2016 dataset: (157, 10)
# 2017 dataset: (155, 9)
# 2018 dataset: (155, 9)
# 2019 dataset: (156, 9)

# %%
# Detect and remove duplicate rows from df_2015
df_2015 = df_2015.drop_duplicates()

# Detect and remove duplicate rows from df_2016
df_2016 = df_2016.drop_duplicates()

# Detect and remove duplicate rows from df_2017
df_2017 = df_2017.drop_duplicates()

# Detect and remove duplicate rows from df_2018
df_2018 = df_2018.drop_duplicates()

# Detect and remove duplicate rows from df_2019
df_2019 = df_2019.drop_duplicates()

# Verify the shape of each DataFrame after removing duplicates
print("Shape after removing duplicates:")
print("2015 dataset:", df_2015.shape)
print("2016 dataset:", df_2016.shape)
print("2017 dataset:", df_2017.shape)
print("2018 dataset:", df_2018.shape)
print("2019 dataset:", df_2019.shape)
# Out:
# Shape after removing duplicates:
# 2015 dataset: (158, 10)
# 2016 dataset: (157, 10)
# 2017 dataset: (155, 9)
# 2018 dataset: (155, 9)
# 2019 dataset: (156, 9)

# %%
# Rename 'Country or region' column to 'Country' for df_2018
df_2018 = df_2018.rename(columns={'Country or region': 'Country'})

# Rename 'Country or region' column to 'Country' for df_2019
df_2019 = df_2019.rename(columns={'Country or region': 'Country'})

# Verify the column names for each DataFrame after renaming
print("Column names after renaming:")
print("2018 dataset:", df_2018.columns)
print("2019 dataset:", df_2019.columns)
# Out:
# Column names after renaming:
# 2018 dataset: Index(['Overall rank', 'Country', 'Score', 'GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')
# 2019 dataset: Index(['Overall rank', 'Country', 'Score', 'GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
# Perform inner join operation on 'Country' column across all datasets
common_countries = set(df_2015['Country']).intersection(df_2016['Country'], df_2017['Country'], df_2018['Country'], df_2019['Country'])

# Filter each DataFrame to keep only the rows with common countries
df_2015 = df_2015[df_2015['Country'].isin(common_countries)]
df_2016 = df_2016[df_2016['Country'].isin(common_countries)]
df_2017 = df_2017[df_2017['Country'].isin(common_countries)]
df_2018 = df_2018[df_2018['Country'].isin(common_countries)]
df_2019 = df_2019[df_2019['Country'].isin(common_countries)]

# Verify the shape of each DataFrame after filtering
print("Shape after filtering for common countries:")
print("2015 dataset:", df_2015.shape)
print("2016 dataset:", df_2016.shape)
print("2017 dataset:", df_2017.shape)
print("2018 dataset:", df_2018.shape)
print("2019 dataset:", df_2019.shape)
# Out:
# Shape after filtering for common countries:
# 2015 dataset: (140, 10)
# 2016 dataset: (140, 10)
# 2017 dataset: (140, 9)
# 2018 dataset: (140, 9)
# 2019 dataset: (140, 9)

# %%
import numpy as np

# Function to fill NaN values in 'Region' column using values from df_2015 and df_2016
def fill_region_nan(df, df_2015, df_2016):
    # Create a dictionary mapping countries to regions from df_2015 and df_2016
    country_to_region_2015 = df_2015.set_index('Country')['Region'].to_dict()
    country_to_region_2016 = df_2016.set_index('Country')['Region'].to_dict()
    
    # Fill NaN values in 'Region' column using values from df_2015 and df_2016
    df['Region'] = df['Country'].map(lambda x: country_to_region_2015.get(x, country_to_region_2016.get(x, np.nan)))
    return df

# Fill NaN values in 'Region' column for df_2017, df_2018, and df_2019
df_2017 = fill_region_nan(df_2017, df_2015, df_2016)
df_2018 = fill_region_nan(df_2018, df_2015, df_2016)
df_2019 = fill_region_nan(df_2019, df_2015, df_2016)

# Verify the first few rows of each DataFrame after filling NaN values in 'Region' column
print("First few rows after filling NaN values in 'Region' column:")
print("2017 dataset:")
print(df_2017.head())
print("\n2018 dataset:")
print(df_2018.head())
print("\n2019 dataset:")
print(df_2019.head())
# Out:
# First few rows after filling NaN values in 'Region' column:
# 2017 dataset:
#        Country  Happiness.Rank  Happiness.Score  Economy..GDP.per.Capita.  \
# 0       Norway               1            7.537                  1.616463
# 1      Denmark               2            7.522                  1.482383
# 2      Iceland               3            7.504                  1.480633
# 3  Switzerland               4            7.494                  1.564980
# 4      Finland               5            7.469                  1.443572
#
#      Family  Health..Life.Expectancy.   Freedom  Generosity  \
# 0  1.533524                  0.796667  0.635423    0.362012
# 1  1.551122                  0.792566  0.626007    0.355280
# 2  1.610574                  0.833552  0.627163    0.475540
# 3  1.516912                  0.858131  0.620071    0.290549
# 4  1.540247                  0.809158  0.617951    0.245483
#
#    Trust..Government.Corruption.          Region
# ...

# %%
# Add a 'Year' column to each dataset
df_2015['Year'] = 2015
df_2016['Year'] = 2016
df_2017['Year'] = 2017
df_2018['Year'] = 2018
df_2019['Year'] = 2019

# Verify the first few rows of each DataFrame after adding the 'Year' column
print("First few rows after adding the 'Year' column:")
print("2015 dataset:")
print(df_2015.head())
print("\n2016 dataset:")
print(df_2016.head())
print("\n2017 dataset:")
print(df_2017.head())
print("\n2018 dataset:")
print(df_2018.head())
print("\n2019 dataset:")
print(df_2019.head())
# Out:
# First few rows after adding the 'Year' column:
# 2015 dataset:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Year
# ...

# %%
print("Column names for 2015 dataset:")
print(df_2015.columns)

print("\nColumn names for 2016 dataset:")
print(df_2016.columns)

print("\nColumn names for 2017 dataset:")
print(df_2017.columns)

print("\nColumn names for 2018 dataset:")
print(df_2018.columns)

print("\nColumn names for 2019 dataset:")
print(df_2019.columns)
# Out:
# Column names for 2015 dataset:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Year'],
#       dtype='object')
#
# Column names for 2016 dataset:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Year'],
#       dtype='object')
#
# Column names for 2017 dataset:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score',
#        'Economy..GDP.per.Capita.', 'Family', 'Health..Life.Expectancy.',
#        'Freedom', 'Generosity', 'Trust..Government.Corruption.', 'Region',
#        'Year'],
#       dtype='object')
#
# Column names for 2018 dataset:
# Index(['Overall rank', 'Country', 'Score', 'GDP per capita', 'Social support',
# ...

# %%
# Rename columns in df_2017
df_2017 = df_2017.rename(columns={'Happiness.Score': 'Happiness Score','Happiness.Rank': 'Happiness Rank',
                                  'Economy..GDP.per.Capita.': 'Economy (GDP per Capita)',
                                  'Health..Life.Expectancy.': 'Health (Life Expectancy)',
                                  'Trust..Government.Corruption.': 'Trust (Government Corruption)'})

# Rename columns in df_2018 and df_2019
df_2018 = df_2018.rename(columns={'Overall rank': 'Happiness Rank', 'Score': 'Happiness Score',
                                  'GDP per capita': 'Economy (GDP per Capita)', 'Social support': 'Family',
                                  'Healthy life expectancy': 'Health (Life Expectancy)',
                                  'Freedom to make life choices': 'Freedom',
                                  'Perceptions of corruption': 'Trust (Government Corruption)'})
df_2019 = df_2019.rename(columns={'Overall rank': 'Happiness Rank', 'Score': 'Happiness Score',
                                  'GDP per capita': 'Economy (GDP per Capita)', 'Social support': 'Family',
                                  'Healthy life expectancy': 'Health (Life Expectancy)',
                                  'Freedom to make life choices': 'Freedom',
                                  'Perceptions of corruption': 'Trust (Government Corruption)'})

# %%
# Reorder columns in each dataset
column_order = ['Country', 'Region', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)',
                'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
                'Generosity', 'Year']

df_2015 = df_2015[column_order]
df_2016 = df_2016[column_order]
df_2017 = df_2017[column_order]
df_2018 = df_2018[column_order]
df_2019 = df_2019[column_order]

# Verify the column order for each dataset
print("Column order for each dataset:")
print("2015 dataset:", df_2015.columns)
print("2016 dataset:", df_2016.columns)
print("2017 dataset:", df_2017.columns)
print("2018 dataset:", df_2018.columns)
print("2019 dataset:", df_2019.columns)
# Out:
# Column order for each dataset:
# 2015 dataset: Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Year'],
#       dtype='object')
# 2016 dataset: Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Year'],
#       dtype='object')
# 2017 dataset: Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Year'],
#       dtype='object')
# 2018 dataset: Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
# ...

# %%
# Concatenate all datasets into one DataFrame
merged_df = pd.concat([df_2015, df_2016, df_2017, df_2018, df_2019], ignore_index=True)

# Verify the shape and first few rows of the merged dataset
print("Shape of the merged dataset:", merged_df.shape)
print("\nFirst few rows of the merged dataset:")
print(merged_df.head())
# Out:
# Shape of the merged dataset: (700, 11)
#
# First few rows of the merged dataset:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Year
# ...

# %%
merged_df.head(500)
# Out:
#                 Country                           Region  Happiness Rank  \
# 0           Switzerland                   Western Europe               1
# 1               Iceland                   Western Europe               2
# 2               Denmark                   Western Europe               3
# 3                Norway                   Western Europe               4
# 4                Canada                    North America               5
# ..                  ...                              ...             ...
# 495             Croatia       Central and Eastern Europe              82
# 496  Dominican Republic      Latin America and Caribbean              83
# 497             Algeria  Middle East and Northern Africa              84
# 498             Morocco  Middle East and Northern Africa              85
# 499               China                     Eastern Asia              86
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# ...

# %%
# Save the merged DataFrame as a CSV file
merged_df.to_csv('merged_dataset.csv', index=False)

# %%
# Set Seaborn style
sns.set_style("whitegrid")

# Create the line plot
plt.figure(figsize=(10, 6))
sns.lineplot(data=merged_df, x='Year', y='Happiness Score', ci=None)

# Set the title and labels
plt.title('Evolution of Happiness Score (2015-2019)', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Happiness Score', fontsize=14)

# Show the plot
plt.show()

# %%
# Create the boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(data=merged_df, x='Year', y='Happiness Score')

# Set the title and labels
plt.title('Distribution of Happiness Score by Year (2015-2019)', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Happiness Score', fontsize=14)

# Show the plot
plt.show()

# %%
# Create a grouped barplot for each year
plt.figure(figsize=(12, 8))

# Define the number of bins and their width
num_bins = 11  # Number of bins (0-10)
bin_width = 0.15  # Width of each bin

# Define colors for each year
colors = sns.color_palette('muted', n_colors=len(merged_df['Year'].unique()))

# Define the positions for each group of bars
positions = np.arange(num_bins)

# Iterate over each year
for i, year in enumerate(merged_df['Year'].unique()):
    # Filter data for the current year
    year_data = merged_df[merged_df['Year'] == year]
    
    # Calculate histogram counts
    counts, bins = np.histogram(year_data['Happiness Score'], bins=num_bins, range=(0, 10))
    
    # Plot the grouped barplot
    plt.bar(positions + (bin_width * i), counts, width=bin_width, align='center', label=year, color=colors[i], alpha=0.7)

# Set the title and labels
plt.title('Distribution of Happiness Score by Year (2015-2019)', fontsize=16)
plt.xlabel('Happiness Score', fontsize=14)
plt.ylabel('Number of Countries', fontsize=14)

# Set the x-axis ticks and labels
plt.xticks(positions + (bin_width * (len(merged_df['Year'].unique()) - 1) / 2), range(0, num_bins))

# Add legend
plt.legend(title='Year', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Create a boxplot for each region per year
plt.figure(figsize=(12, 8))

# Create boxplot using Seaborn
box_plot = sns.boxplot(data=merged_df, x='Year', y='Happiness Score', hue='Region')

# Set the title and labels
plt.title('Boxplot of Happiness Score by Region and Year (2015-2019)', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Happiness Score', fontsize=14)

# Add legend
box_plot.legend(title='Region', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Create a boxplot for GDP per capita (BBP) for each region
plt.figure(figsize=(12, 8))

# Create boxplot using Seaborn
sns.boxplot(data=merged_df, x='Region', y='Economy (GDP per Capita)')

# Set the title and labels
plt.title('Importance of GDP per Capita for Happiness Score by Region (2015-2019)', fontsize=16)
plt.xlabel('Region', fontsize=14)
plt.ylabel('Economy (GDP per Capita)', fontsize=14)

plt.xticks(rotation=45)
# Show the plot
plt.tight_layout()
plt.show()

# %%
def search_countries_by_happiness_score(df, min_score, max_score):
    
    # Calculate the average happiness score across the 5 years for each country
    average_scores_per_country = df.groupby('Country')['Happiness Score'].mean()
    
    # Filter countries based on average happiness score range
    filtered_countries = average_scores_per_country[(average_scores_per_country >= min_score) & (average_scores_per_country <= max_score)]
    
    return filtered_countries.index.tolist()

# Example usage:
min_score = 5.0
max_score = 6.0
countries_within_range = search_countries_by_happiness_score(merged_df, min_score, max_score)
print("Countries within the happiness score range:", countries_within_range)
# Out:
# Countries within the happiness score range: ['Algeria', 'Azerbaijan', 'Belarus', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'China', 'Croatia', 'Cyprus', 'Dominican Republic', 'Ecuador', 'Estonia', 'Greece', 'Honduras', 'Hungary', 'Indonesia', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kosovo', 'Kyrgyzstan', 'Latvia', 'Lebanon', 'Libya', 'Lithuania', 'Malaysia', 'Mauritius', 'Moldova', 'Mongolia', 'Montenegro', 'Morocco', 'Nigeria', 'Pakistan', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Romania', 'Russia', 'Serbia', 'Slovenia', 'South Korea', 'Tajikistan', 'Turkey', 'Turkmenistan', 'Venezuela', 'Vietnam']

# %%
def search_country_by_name(df, country_name):
    
    # Filter DataFrame based on country name
    filtered_df = df[df['Country'] == country_name]
    
    return filtered_df

# Example usage:
country_name = 'Belgium'
country_data = search_country_by_name(merged_df, country_name)
print("Data for", country_name, ":", country_data)
# Out:
# Data for Belgium :      Country          Region  Happiness Rank  Happiness Score  \
# 18   Belgium  Western Europe              19            6.937
# 156  Belgium  Western Europe              18            6.929
# 296  Belgium  Western Europe              17            6.891
# 435  Belgium  Western Europe              16            6.927
# 577  Belgium  Western Europe              18            6.923
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 18                   1.307820  1.285660                  0.896670  0.584500
# 156                  1.425390  1.052490                  0.819590  0.513540
# 296                  1.463781  1.462313                  0.818092  0.539771
# 435                  1.324000  1.483000                  0.894000  0.583000
# 577                  1.356000  1.504000                  0.986000  0.473000
#
#      Trust (Government Corruption)  Generosity  Year
# 18                        0.225400    0.222500  2015
# ...

# %%
import matplotlib.pyplot as plt

def plot_country_happiness_evolution(df, country_name):
    
    # Filter DataFrame for the specified country
    country_data = df[df['Country'] == country_name]
    
    # Plot the evolution of happiness score over the years
    plt.figure(figsize=(10, 6))
    plt.plot(country_data['Year'], country_data['Happiness Score'], marker='o', linestyle='-')
    plt.title(f'Evolution of Happiness Score over the Years for {country_name}')
    plt.xlabel('Year')
    plt.ylabel('Happiness Score')
    plt.grid(True)
    plt.show()

# Example usage:
country_name = "Belgium"  # Example country name
plot_country_happiness_evolution(merged_df, country_name)

# %%
def search_countries_by_avg_gdp_range(df, min_avg_gdp, max_avg_gdp):
    
    # Calculate the average GDP per capita across the 5 years for each country
    avg_gdp_per_country = df.groupby('Country')['Economy (GDP per Capita)'].mean()
    
    # Filter countries based on average GDP per capita range
    filtered_countries = avg_gdp_per_country[(avg_gdp_per_country >= min_avg_gdp) & (avg_gdp_per_country <= max_avg_gdp)]
    
    # Get the names of the filtered countries
    countries_within_avg_gdp_range = filtered_countries.index.tolist()
    
    return countries_within_avg_gdp_range

# Example usage:
min_avg_gdp = 1.3  # Example minimum average GDP per capita
max_avg_gdp = 1.4  # Example maximum average GDP per capita
countries_within_avg_gdp_range = search_countries_by_avg_gdp_range(merged_df, min_avg_gdp, max_avg_gdp)
print("Countries within the average GDP per capita range:")
print(countries_within_avg_gdp_range)
# Out:
# Countries within the average GDP per capita range:
# ['Australia', 'Austria', 'Bahrain', 'Belgium', 'Canada', 'Denmark', 'Finland', 'France', 'Germany', 'Iceland', 'Israel', 'Italy', 'Japan', 'New Zealand', 'South Korea', 'United Kingdom']

# %%
def compare_countries_happiness(df, country1, country2):
    
    # Filter DataFrame for the two countries
    country1_data = df[df['Country'] == country1]
    country2_data = df[df['Country'] == country2]
    
    # Display the happiness scores of the two countries
    comparison_df = pd.concat([country1_data, country2_data])
    
    return comparison_df

# Example usage:
country1_name = "Denmark"
country2_name = "Switzerland"
comparison_data = compare_countries_happiness(merged_df, country1_name, country2_name)
print("Comparison of happiness scores for", country1_name, "and", country2_name)
print(comparison_data[['Country', 'Year', 'Happiness Score']])
# Out:
# Comparison of happiness scores for Denmark and Switzerland
#          Country  Year  Happiness Score
# 2        Denmark  2015            7.527
# 140      Denmark  2016            7.526
# 281      Denmark  2017            7.522
# 422      Denmark  2018            7.555
# 561      Denmark  2019            7.600
# 0    Switzerland  2015            7.587
# 141  Switzerland  2016            7.509
# 283  Switzerland  2017            7.494
# 424  Switzerland  2018            7.487
# 565  Switzerland  2019            7.480
